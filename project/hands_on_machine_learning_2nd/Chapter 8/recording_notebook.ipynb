# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_import = pd.read_csv("creditcard.csv")
data_import
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
284000*31
# Out:
# 8804000

# %%
sampled_data = data_import.sample(30000)
unused = sampled_data[["Time", "Amount"]]
y = sampled_data["Class"]
X = sampled_data.iloc[:, 1:-2]
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0aaea714cfd1> in <module>
# ----> 1 sampled_data = data_import.sample(0.1)
#       2 unused = sampled_data[["Time", "Amount"]]
#       3 y = sampled_data["Class"]
#       4 X = sampled_data.iloc[:, 1:-2]
#       5 X
#
# /opt/miniconda3/envs/hands_on_ml/lib/python3.9/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5336             )
#    5337         elif n is not None and frac is None and n % 1 != 0:
# -> 5338             raise ValueError("Only integers accepted as `n` values")
#    5339         elif n is None and frac is not None:
#    5340             n = int(round(frac * axis_length))
#
# ValueError: Only integers accepted as `n` values

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
X10D = pca.fit_transform(X)
X10D = pd.DataFrame(X10D)
X10D
# Out:
#                 0          1         2         3         4         5  \
# 0        1.359937   0.072902 -2.536141  1.377686  0.343614  0.463291
# 1       -1.191898  -0.266089 -0.167266  0.446644 -0.061729 -0.079605
# 2        1.358588   1.340725 -1.775149  0.373755  0.512057  1.812941
# 3        0.966150   0.185003 -1.793725 -0.866840  0.000656  1.252941
# 4        1.158409  -0.877678 -1.547708  0.404160  0.414811  0.094326
# ...           ...        ...       ...       ...       ...       ...
# 284802  11.881221 -10.071528  9.834035 -2.068208  5.374599 -2.601189
# 284803   0.733039   0.055261 -2.035076 -0.742708 -0.861657  1.066216
# 284804  -1.919542   0.301304  3.249684 -0.557796 -2.629025  3.030874
# 284805   0.240715  -0.530368 -0.700630  0.693302  0.391731  0.618265
# 284806   0.533534   0.189897 -0.703147 -0.506048  0.018201 -0.650026
#
#                6         7         8         9
# 0       0.252213 -0.086955  0.350976 -0.094988
# 1      -0.075375 -0.085718 -0.263425  0.168905
# 2       0.835081 -0.218269 -1.599071 -0.231869
# 3       0.234672 -0.391283 -1.406991  0.048970
# 4       0.602667  0.285501  0.806437 -0.761797
# ...          ...       ...       ...       ...
# 284802 -4.880092 -7.297051  1.916628 -4.352702
# 284803  0.050982 -0.278665  0.524905  0.958639
# 284804 -0.290583 -0.705333  0.430083  0.489207
# 284805 -0.675120 -0.660613  0.392003  0.384960
# 284806  1.586793  0.430816  0.461863  0.908536
#
# [284807 rows x 10 columns]

# %%
Xinverse = pca.inverse_transform(X10D)
Xinverse
# Out:
# array([[-1.35993708e+00, -7.29034501e-02,  2.53613410e+00, ...,
#          8.93172574e-06,  7.78765751e-06,  1.96442665e-06],
#        [ 1.19189842e+00,  2.66088867e-01,  1.67264088e-01, ...,
#          1.64812051e-05, -1.15070107e-05, -1.48399228e-06],
#        [-1.35859115e+00, -1.34073774e+00,  1.77519049e+00, ...,
#          2.81421661e-04, -4.44807136e-05, -9.09810664e-06],
#        ...,
#        [ 1.91954426e+00, -3.01295945e-01, -3.24968141e+00, ...,
#         -8.02269114e-05,  2.15511586e-05,  1.12380220e-06],
#        [-2.40713602e-01,  5.30372440e-01,  7.00613903e-01, ...,
#         -4.84331409e-05, -9.68711666e-08,  1.20864731e-06],
#        [-5.33535501e-01, -1.89902167e-01,  7.03164317e-01, ...,
#         -9.98382490e-05, -1.82330063e-05,  9.44354485e-07]])

# %%
pca = PCA()
XD = pca.fit(X)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum>=0.95)
d
# Out:
# 21

# %%
cumsum
# Out:
# array([0.12483757, 0.21356702, 0.28837636, 0.35360784, 0.41559829,
#        0.47335421, 0.52315273, 0.56956969, 0.60884466, 0.64742333,
#        0.68132481, 0.71381239, 0.7460451 , 0.77594586, 0.80320759,
#        0.82819207, 0.85166522, 0.87452552, 0.89608823, 0.91542731,
#        0.93298321, 0.95011992, 0.96280874, 0.97474451, 0.9835865 ,
#        0.99115334, 0.99645466, 1.        ])

# %%
plt.plot(cumsum)

# %%
# Out:
#                 0          1         2         3         4         5  \
# 0        1.359706   0.073376 -2.537433  1.376302  0.336504  0.455068
# 1       -1.191776  -0.266557 -0.165950  0.449200 -0.059248 -0.082115
# 2        1.357901   1.343697 -1.776618  0.375742  0.495269  1.787743
# 3        0.966225   0.186300 -1.792687 -0.865579  0.007881  1.250027
# 4        1.158041  -0.876547 -1.550200  0.400225  0.404513  0.089631
# ...           ...        ...       ...       ...       ...       ...
# 284802  11.881346 -10.073711  9.836930 -2.056864  5.370754 -2.609180
# 284803   0.732222   0.059761 -2.038752 -0.747018 -0.878940  1.045729
# 284804  -1.919871   0.303422  3.247486 -0.562883 -2.635679  3.030458
# 284805   0.240592  -0.532178 -0.702165  0.693522  0.380513  0.612424
# 284806   0.532936   0.193358 -0.706563 -0.513779  0.004792 -0.653615
#
#                6         7         8         9
# 0       0.240414 -0.102684  0.346226  0.144989
# 1      -0.077340 -0.083444 -0.227297 -0.182514
# 2       0.781933 -0.239164 -1.498119  0.129069
# 3       0.233636 -0.367212 -1.346642 -0.167223
# 4       0.592889  0.266652  0.749452  0.832748
# ...          ...       ...       ...       ...
# 284802 -4.897033 -7.315797  1.479472  4.371836
# 284803  0.011223 -0.282652  0.720696 -0.852608
# 284804 -0.313307 -0.702525  0.509328 -0.388682
# 284805 -0.670659 -0.694432  0.339270 -0.395895
# 284806  1.560339  0.423034  0.599621 -0.820505
#
# [284807 rows x 10 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.decomposition import KernelPCA

clf = Pipeline([
								("kpca", KernelPCA(n_components=2)),
								("log_reg", LogisticRegression())
])

param_grid = [{
							"kpca__gamma":np.linspace(0.03, 0.05, 10),
							"kpca__kernel":["rbf", "sigmoid"]
}]

grid_search = GridSearchCV(clf, param_grid, cv=3)
grid_search.fit(X, y)

# %%
np.linspace(0.03, 0.05, 10)
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:327199)
# at w.execute (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:326520)
# at w.start (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:322336)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336863)
# at async t.CellExecutionQueue.start (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336403)

# %%
print(grid_search.best_params_)
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:327199)
# at w.execute (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:326520)
# at w.start (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:322336)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336863)
# at async t.CellExecutionQueue.start (/Users/g42v/.vscode/extensions/ms-toolsai.jupyter-2021.8.1236758218/out/client/extension.js:90:336403)
